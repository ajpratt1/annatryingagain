# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %%
#UFO SIGHTINGS

import matplotlib.pyplot as plt
import pandas as pd

df3 = pd.read_csv('/Users/annajacobson/Documents/GitHub/annatryingagain/Paranormal Activity/CSVs/ufo_sightings_all.csv')
df3['Date'] = pd.to_datetime(df3['Date'])
df3.set_index('Date', inplace=True)

yearly_counts = df3.resample('Y').size()

date_series = pd.DataFrame({'Date': yearly_counts.index, 'ufo sightings/year': yearly_counts.values})
date_series.set_index('Date', inplace=True)

ax = date_series.plot()
ax.set_ylabel("# of UFO Sightings Reported in the US")
plt.title("UFO Sightings Reported in United States 1958-2022")
plt.show()

# %%
#BIGFOOT

df4 = pd.read_csv('/Users/annajacobson/Documents/GitHub/annatryingagain/Paranormal Activity/CSVs/bigfoot_sightings.csv')
df4['Year'] = pd.to_datetime(df4['Year'], format='%Y')

df4.set_index('Year', inplace=True)

bf_yearly_counts = df4.resample('Y').size()

bf_date_series = pd.DataFrame({'date': bf_yearly_counts.index, 'bigfoot sightings/year': bf_yearly_counts.values})

bf_date_series.set_index('date', inplace=True)

ax2 = bf_date_series.plot()
ax2.set_ylabel("# of Bigfoot Sightings Reported in the US")
plt.title("Bigfoot Sightings Reported in United States 1958-2022")
plt.show()

# %%
# Concatenate the two DataFrames vertically
combined_counts = pd.concat([yearly_counts, bf_yearly_counts], axis=1)

# Rename the columns
combined_counts.columns = ['ufo_sightings', 'bigfoot_sightings']

# Write the combined DataFrame to a CSV file
combined_counts.to_csv('Users/annajacobson/Documents/GitHub/annatryingagain/Paranormal Activity/CSVs/combined_sightings_output.csv')

# %%
# Create a sample dataframe
df = pd.read_csv("/Users/annajacobson/Documents/GitHub/annatryingagain/Paranormal Activity/CSVs/combined_sightings.csv")
df2 = pd.read_csv("/Users/annajacobson/Documents/GitHub/annatryingagain/Paranormal Activity/CSVs/govtrust.csv")

fig, ax = plt.subplots()

# Plot total sightings
ax.plot(df['Year'], df['Total Sightings'], color='red', label='Total Paranormal Sightings')

# Add legend for total sightings
ax.legend(bbox_to_anchor=(1.05, -.25), loc='lower right', borderaxespad=0)

# Set x and y labels
ax.set_xlabel("Year")
ax.set_ylabel("Total Paranormal Sightings Reported in US")

# Add second y-axis for government trust
ax2=ax.twinx()
ax2.plot(df2['Year'], df2['gov_trust_whole'], color="orange", label='Public Trust in US Government')

# Add legend for government trust
ax2.legend(bbox_to_anchor=(.45, -.25), loc='lower right', borderaxespad=0)
# Set y-label for government trust
ax2.set_ylabel("% Public Trust in US Government")
plt.title(" Paranormal Sighting Reports and US Government Trust 1958-2022")
ax.grid(which = "major")
ax.grid( which = "minor", color = "gainsboro")
ax.minorticks_on()
plt.show()

# %%
df = pd.read_csv("/Users/annajacobson/Documents/GitHub/annatryingagain/Paranormal Activity/CSVs/combined_sightings.csv")

fig, ax3 = plt.subplots()

ax3.plot(df['Year'], df['UFO Sightings'], color='darkolivegreen', label='UFO Sightings Reported in US')
ax3.legend(bbox_to_anchor=(1.05, -.25), loc='lower right', borderaxespad=0)

ax3.set_xlabel("Date")
ax3.set_ylabel("Total UFO Sightings Reported in US")

ax4=ax3.twinx()
ax4.plot(df['Year'], df['Bigfoot Sightings'], color="darkgoldenrod", label='Bigfoot Sightings Reported in US')
ax4.legend(bbox_to_anchor=(.45, -.25), loc='lower right', borderaxespad=0)
ax4.set_ylabel("Total Bigfoot Sightings Reported in US")

plt.title(" Paranormal Sighting Reports Reported 1958-2022")
plt.show()

# %%
x = df2['Year']
y = df2['gov_trust_whole']

plt.plot(x, y, color='orange')
plt.xlabel('Year')
plt.ylabel('% Public Trust in US Government')
# Out:
# Text(0, 0.5, '% Public Trust in US Government')
